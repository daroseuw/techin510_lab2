# %% [markdown]
# # LAB2: DATA VISUALIZATION & PROCESSING IN PYTHON
# In this lab you will practice Python data processing and visualization.

# %% [markdown]
# ## Step 1: Access the datasets
#
# You can access the data files for `Lab_2` on Canvas in the `Files/Lab 2` section of *TECHIN 510*, and then upload them to your local Jupyter server.
# * Robot Faces data set
# * People
# * Pre-recorded accelerometer data
#
# And you can incorporate them into your code using the sample code in the next cell.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (1.5.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pytz>=2020.1 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from pandas) (1.24.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (1.24.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (3.6.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from matplotlib) (1.24.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: six>=1.5 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (0.12.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas>=0.25 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from seaborn) (1.5.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from seaborn) (1.24.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from seaborn) (3.6.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\dariu\onedrive\documents\gix\msti\winter 2023\510\week 3\wk3_virtual_env\lib\site-packages (22.2.2)
# Collecting pip
#   Using cached pip-22.3.1-py3-none-any.whl (2.1 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.2.2
#     Uninstalling pip-22.2.2:
#       Successfully uninstalled pip-22.2.2
# Successfully installed pip-22.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
## SAMPLE CODE
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
f1 = 'robot_faces.csv'
f2 = 'people.csv'
f3 = 'accelerometer.csv'
faces = pd.read_csv(f1)
people = pd.read_csv(f2)
accel = pd.read_csv(f3)

# %% [markdown]
# ## Step 2: Robot face data exploration
#
# Let's start by exploring the data in `robot_faces.csv`. First, write the code for loading and preprocessing the data. After inspecting the different column names to better understand what the data includes, pose a specific question and write new code to answer that question. Some example questions are:
# * How many robots both have a mouth and a nose?
# * Which country has the highest fraction of robots with black face color?
# * Do more robots built after 2012 have blue eyes than those built before?
#
# Your code should print the question at the beginning and print the computed answer at the end. Your script should also create at least one visualization that allows a human to answer the same question without having to do calculations.
#
# *If you are interested, you can read more about the face data [here](https://spectrum.ieee.org/automaton/robotics/humanoids/what-people-see-in-157-robot-faces).*

# %%
faces.columns
# Out:
# Index(['Name', 'Unnamed: 1', 'robot type', 'category', 'full head',
#        'screen type', 'mouth', 'nose', 'eyebrows', 'cheeks (blush)', 'hair',
#        'ears', 'physical features', 'robot height', 'embodiment', 'face color',
#        'face turns other colors', 'face gradient to', 'face shape',
#        'screen size', 'head motion', 'face motion', 'info display',
#        'eye color', 'eye outline color', 'eye turns other colors (inside)',
#        'eye shape', 'eye turns other shapes (exclude blink)', 'pupil (y/n)',
#        'pupil color', 'lid', 'lid color', 'iris', 'iris color', 'lashes color',
#        'lash shape', 'reflected glare color', '# glare circles', 'blink type',
#        'pupil\nshapes', 'eye motion', 'pupil and/or\niris motion',
#        'glare motion', 'wink', 'eye size', 'eye placement', 'eye spacing',
#        'mouth color (or outline color)', 'mouth inside color', 'mouth shape',
#        'lips', 'tongue', 'teeth shape', 'mouth motion', 'mouth length',
#        'mouth placement', 'nose color', 'nose shape', 'nose 3d', 'nose size',
#        'nose placement', 'nose motion', 'eyebrow color', 'eyebrow shape',
#        'eyebrow inner edge positions', 'eyebrow independent motion',
#        'eyebrow motion', 'eyebrow length', 'eyebrow arch', 'cheek color',
#        'cheek shape', 'cheek size', 'cheek placement', 'cheek spacing',
#        'hair color', 'country/region of origin', 'year'],
#       dtype='object')

# %%
column_counts = [len(faces.columns), len(people.columns), len(accel.columns)]

# %%
pd.options.display.max_columns = max(column_counts)
pd.options.display.max_columns
# Out:
# 77

# %%
faces
# Out:
#                  Name  Unnamed: 1  robot type       category full head  \
# 0             Vanessa           7    humanoid        service         y
# 1               EDGAR           8    humanoid       research         y
# 2              FURo-S           8    humanoid        service         y
# 3              FURo-D           9    humanoid        service         y
# 4             SociBot           9    humanoid  entertainment         y
# ..                ...         ...         ...            ...       ...
# 131       Baxter (12)          51    humanoid       research         x
# 132               Eva          51    humanoid        service         x
# 133    Gongzi Xiaobai          51    humanoid           home         x
# 134  Baidu KFC Robot           53    humanoid        service         x
# 135              Otto          55  mechanical           home         x
#
#     screen type mouth nose eyebrows cheeks (blush) hair ears  \
# 0         smart     y    y        y              y    y    y
# 1          back     y    y        y              y    y    y
# 2          blcd     y    y        y              y    y    x
# 3          blcd     y    y        y              y    y    x
# 4          back     y    y        y              y    x    x
# ..          ...   ...  ...      ...            ...  ...  ...
# 131       touch     x    x        x              x    x    x
# 132        blcd     y    x        x              x    x    x
# 133        blcd     x    x        x              x    x    x
# 134        blcd     x    x        x              x    x    x
# 135        blcd     x    x        x              x    x    x
#
#     physical features robot height                   embodiment face color  \
# 0                   x          low           on mobile platform      beige
# 1                   x         high          torso (on platform)      beige
# 2                ears         high              full robot body      beige
# 3                ears         high              full robot body      beige
# 4                ears         high           on mobile platform      beige
# ..                ...          ...                          ...        ...
# 131                 x         high          torso (on platform)      black
# 132                 x         high      upright mobile cylinder      black
# 133                 x       ground  upright stationary cylinder      black
# 134                 x        group                     tabletop      black
# 135                 x       ground              tabletop mobile      black
#
#     face turns other colors face gradient to                face shape  \
# 0                         x                x                     human
# 1                     white                x                     human
# 2                         x                x  rounded rectangle - vert
# 3                         x                x  rounded rectangle - vert
# 4                         y                x                     human
# ..                      ...              ...                       ...
# 131                       x                x         rectangle - horiz
# 132                 no data                x              oval - horiz
# 133                       x                x              oval - horiz
# 134                       x                x           ellipse - horiz
# 135                       x                x            ellipse - vert
#
#     screen size       head motion face motion         info display eye color  \
# 0         small                 y          ud  smart, toolbar[top]     white
# 1         small             x,y,z        none                    x     brown
# 2           med  x, y, vx, vy, vz        none                chest     white
# 3           med  x, y, vx, vy, vz        none                chest     white
# 4         small           x, y, z        none                    x     white
# ..          ...               ...         ...                  ...       ...
# 131       small               x,y        none              no data     white
# 132       small           no data     no data                    x      blue
# 133         med              none        none            text, dis      blue
# 134         med                 x        none                    x    yellow
# 135       small              y, z        none                 icon     white
#
#     eye outline color eye turns other colors (inside)   eye shape  \
# 0               black                               x   human eye
# 1                   x                               x   human eye
# 2               black                               x   human eye
# 3               black                               x   human eye
# 4                   x                               x   human eye
# ..                ...                             ...         ...
# 131                 x                               x      circle
# 132                 x                               x  horiz oval
# 133                 x                               x  horiz oval
# 134                 x                               x   vert rect
# 135                 x                               x      circle
#
#     eye turns other shapes (exclude blink) pupil (y/n) pupil color lid  \
# 0                                        x           y       black   y
# 1                                        x           y     no data   y
# 2                                        x           y       black   y
# 3                                        x           y       black   y
# 4                      other h. eye shapes           y       black   y
# ..                                     ...         ...         ...  ..
# 131                                      x           y       black   x
# 132                                no data           x           x   x
# 133                heart, semicircle, line           x           x   x
# 134                             semicircle           x           x   x
# 135                                      x           x           x   x
#
#     lid color     iris     iris color lashes color lash shape  \
# 0       beige        y           blue        black      human
# 1       beige  no data        no data      no data    no data
# 2       brown        y          hazel        brown      human
# 3       brown        y          hazel        brown      human
# 4       beige        y  blue, various        black      human
# ..        ...      ...            ...          ...        ...
# 131         x        x              x            x          x
# 132         x        x              x            x          x
# 133         x        x              x            x          x
# 134         x        x              x            x          x
# 135         x        x              x            x          x
#
#     reflected glare color # glare circles   blink type pupil\nshapes  \
# 0                   white               1     lid down        circle
# 1                 no data         no data     lid down        circle
# 2                   white               1     lid down        circle
# 3                       x               x     lid down        circle
# 4                       x               x     lid down        circle
# ..                    ...             ...          ...           ...
# 131                     x               x            x        circle
# 132                     x               x      no data             x
# 133                     x               x         slit             x
# 134                     x               x  wipe center             x
# 135                     x               x  wipe center             x
#
#      eye motion pupil and/or\niris motion glare motion     wink eye size  \
# 0          none                      none         none  no data    small
# 1          none                   no data      no data        x    small
# 2          none                    lr, ud         none        x      pro
# 3          none                    lr, ud         none        x      pro
# 4          none                    up, lr         none        y      pro
# ..          ...                       ...          ...      ...      ...
# 131           x                         x            x        x      pro
# 132     no data                         x            x  no data    small
# 133  lr, resize                         x            x        x      dom
# 134  resize, ud                      none            x        y      pro
# 135           x                         x            x        x    small
#
#     eye placement eye spacing mouth color (or outline color)  \
# 0           raise       close                           pink
# 1           raise      medium                          beige
# 2             cen      medium                          brown
# 3             cen      medium                          brown
# 4           raise      medium                           pink
# ..            ...         ...                            ...
# 131            up       close                              x
# 132         raise      medium                              x
# 133           low        wide                              x
# 134           cen      medium                              x
# 135           cen       close                              x
#
#     mouth inside color            mouth shape   lips    tongue  teeth shape  \
# 0                black                  human   pink         x        human
# 1                black                  human  beige  no data         human
# 2                black  crescent, pucker lips   pink         x  single rect
# 3                black  crescent, pucker lips   pink         x  single rect
# 4             dark red                  human   pink      pink        human
# ..                 ...                    ...    ...       ...          ...
# 131                  x                      x      x         x            x
# 132                  x                      x      x         x            x
# 133                  x                      x      x         x            x
# 134                  x                      x      x         x            x
# 135                  x                      x      x         x            x
#
#       mouth motion mouth length mouth placement nose color       nose shape  \
# 0    height, width        short             low      beige            human
# 1    width, height          med            down      beige            human
# 2    height, width          med             cen      beige  rounded pyramid
# 3    width, height          med             cen      beige  rounded pyramid
# 4    height, width          med            down      beige            human
# ..             ...          ...             ...        ...              ...
# 131           none            x               x          x                x
# 132              x            x               x          x                x
# 133           none            x               x          x                x
# 134              x            x               x          x                x
# 135              x            x               x          x                x
#
#     nose 3d nose size nose placement nose motion eyebrow color  \
# 0         y       med            cen        none         black
# 1         y     large           down        none         brown
# 2         y       med            cen        none         brown
# 3         y       med            cen        none         brown
# 4         y     small            cen        none         brown
# ..      ...       ...            ...         ...           ...
# 131       x         x              x        none             x
# 132       x         x              x           x             x
# 133       x         x              x        none             x
# 134       x         x              x           x             x
# 135       x         x              x           x             x
#
#        eyebrow shape eyebrow inner edge positions eyebrow independent motion  \
# 0    arched (center)                   down, flat                          x
# 1    arched (center)                         down                          x
# 2    arched (center)                         down                          y
# 3    arched (center)                         down                          y
# 4              human                   down, flat                          y
# ..               ...                          ...                        ...
# 131                x                            x                          x
# 132                x                            x                          x
# 133                x                            x                          x
# 134                x                            x                          x
# 135                x                            x                          x
#
#     eyebrow motion eyebrow length eyebrow arch cheek color cheek shape  \
# 0             none            med          med        pink          3D
# 1               ud            med        small       beige          3D
# 2               ud            med        small        pink       blush
# 3               ud            med        small        pink       blush
# 4               ud           long        small       peach          3D
# ..             ...            ...          ...         ...         ...
# 131           none              x            x           x           x
# 132           none              x            x           x           x
# 133           none              x            x           x           x
# 134           none              x            x           x           x
# 135           none              x            x           x           x
#
#     cheek size cheek placement cheek spacing hair color  \
# 0        large             cen         close      black
# 1        large              up          wide      brown
# 2            x             cen          wide      brown
# 3          NaN             cen          wide      brown
# 4          med             cen           cen          x
# ..         ...             ...           ...        ...
# 131          x               x             x          x
# 132          x               x             x          x
# 133          x               x             x          x
# 134          x               x             x          x
# 135          x               x             x          x
#
#     country/region of origin  year
# 0                     Russia  2010
# 1                  Singapore  2014
# 2                      Korea  2015
# 3                      Korea  2015
# 4                         UK  2012
# ..                       ...   ...
# 131                      USA  2015
# 132                    China  2015
# 133                    China  2016
# 134                    China  2016
# 135                    Korea  2016
#
# [136 rows x 77 columns]

# %%
## TODO: Write code to ask a question about the face data and answer it both visually and programmatically
robots_w_teeth = faces.loc[(faces['teeth shape'] != 'x')]
robots_wo_teeth = faces.loc[(faces['teeth shape'] == 'x')]
print("How many robots have teeth?")
print(f"There are {len(robots_w_teeth)} robots with teeth.")
# print("Here is a distribution of robots with teeth by region of origin:")
# Out:
# How many robots have teeth?
# There are 24 robots with teeth.

# %% [markdown]
# ## Step 3: Persons data exploration
#
# We continue our exploration of the data by diving into a dataset of notional (100% fake) persons. Just as you did with the Robot data, write the code for loading and preprocessing the Person data. After inspecting the different column names to better understand what the data includes, pose a specific question and write new code to answer that question. Some example questions are:
# * How many males are in the data set vs females?
# * Who are the oldest people living in Chicago?
# * Which city is most popular with people in their 30's?
# * What are the top 5 US states represented in the data?
#
# Your code should print the question at the beginning and print the computed answer at the end. Your script should also create at least one visualization that allows a human to answer the same question without having to do calculations.

# %%
## TODO: Write code to ask a question about the person data and answer it both visually and programmatically

# %% [markdown]
# ## Step 4: Load and visualize accelerometer data
#
# Next you will explore the accelerometer data in `accelerometer.csv` recorded from a mobile device.
#
# The first thing your Python script should do is open the data file and parse its content into Python lists or arrays. Each row in the data file corresponds to one reading. The first value is the time in seconds, and the next three values are the x, y, z acceleration values from a mobile device accelerometer. Your goal for this part of the lab is to obtain four lists or arrays (of same length) each containing the different columns in the data file.
#
# You can use the `pd.read_csv()`, but if you would like to practice some of the string operations we used during the `chatbot` exercise last week, you can open the file, read its content into a single string, and then use the split() function to split into lines (`data_string.split("\n")`) and elements (`data_string.split(",")`).
#
# Before starting to process the data, visualize it to get a better sense of what is in the data. Keep visualization steps in your script for your lab submission.

# %%
## TODO: Code for loading and visualizing accelerometer data

# %% [markdown]
# ## Step 5: Detecting lack of movement
#
# As a first data processing exercise, iterate over the lists or arrays you created to compute the: 1) total amount of time; and 2) percentage of time during which the person holding the mobile device was not moving (e.g., absolute acceleration smaller than ~0.2m/sec^2). Visualize parts of the data where lack of movement is detected together with the original data to verify that it works correctly.

# %%
## TODO: Code for detecting lack of movement (will be run after running code from Step 3)

# %% [markdown]
# ## Step 6: Counting steps
#
# Next you will iterate over the data to count how many steps were taken. There are alternative ways to do that but here we will outline an approximation of the "zero-crossing" method. Walking with an accelerometer results in cyclic patterns characterized by pairs of peaks and valleys in acceleration in some directions. In the provided data you can focus on the z dimension, since the mobile device was held in fixed orientation. To determine the peaks and valleys, iterate over the z values; compare each element in the list to the value of the previous and the next element (note that you cannot do this for the first and last elements of the list); if it is greater than or smaller than both of those, it corresponds to a peak or a valley. Create a separate list, of same length as the data lists, that has the value +1 where peaks occur, -1 where valleys occur, and 0 otherwise. Visualize the peaks and the valleys on the same plot as your data to verify that your algorithm works correctly.
#
# You will see that even very small variations in acceleration cause peaks and valleys, so we need to be stricter in detecting peaks and valleys that correspond to an actual step. For that, you can extend the condition for peaks and valleys to include a threshold on the absolute value (`math.fabs()`) of the acceleration in the z direction (e.g., ~1m/sec^2). Visually inspect the number of peaks and valleys with this stricter criteria.
#
# A rough approximation of the number of steps would be the `math.min()` of the numbers of peaks and number of valleys. If you are out of time for this lab, you can stop here. However, to count pairs of peaks and valleys more strictly, you need to iterate over the list of peaks and valleys to determine the number of times a peak is followed by a valley (or vice versa) within one second or so (i.e., -1 and 1 separated by no more than four 0s in the peak/valley list). So if you have time, implement counting of pairs as a more accurate approximation of the number of steps.
#
# Your script should print the counted number of steps on the terminal at the end.

# %%
## TODO: Code for counting steps in accelerometer data (will be run after Step 4)

# %% [markdown]
# ## Bonus
#
# If you have extra time on this lab, go over your code and add error checks for things that might go wrong, such as if the data file does not have the expected format or if an operation returns empty lists. Instead of throwing errors in these situations, your script should print informative error messages (remember `try`/`except` clauses). In addition, you can go over your code to refactor it into potentially re-usable functions. Finally, you can use the ipywidgets we covered in class to make your figures interactive. Do this part on the code above and list all the improments you made in the text here.

# %% [markdown]
# ## Step 7: Submit your code on Canvas
#
# Complete this lab by submitting this file (`lab2.ipynb`) on Canvas, by January 24, 23:59. We will test your code by manually running them and inspecting the code to verify that:
# * Your face data analysis prints out a clearly stated question and the answer to the question onto the terminal. The code for computing the answer correctly represents the intended question. It also creates an interpretable visualization of parts of the data that would allow a person to answer the same question.
# * Your step counter code visualizes the accelerometer data, clearly showing times where there is no movement and where peaks and valleys are detected by your algorithm. It prints the detected number of steps on the terminal at the end. The detected number is reasonable compared to ground truth and the code corresponds to the described algorithm.
#
# See Canvas for a grading rubric.
